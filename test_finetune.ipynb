# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import torch

from src.training.train import Trainer
from src.finetuning.finetuning import finetune

# %%
finetune("filters_16_do_0.1_od_300/model_loss_0.0661_it_227856.pt")
# Out:
# Total number of trainable parameters: 28335
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/equitempo/lib/python3.9/site-packages/cffi/cparser.py:5
#       4 try:
# ----> 5     from . import _pycparser as pycparser
#       6 except ImportError:
#
# ImportError: cannot import name '_pycparser' from 'cffi' (/homes/cp584/miniconda3/envs/equitempo/lib/python3.9/site-packages/cffi/__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /homes/cp584/EquiTempo/test_finetune.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bbraintree/homes/cp584/EquiTempo/test_finetune.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> finetune("filters_16_do_0.1_od_300/model_loss_0.0661_it_227856.pt")
#
# File ~/EquiTempo/src/finetuning/finetuning.py:47, in finetune(model_name, dataset_name_list)
#      44 dataloader = dataset.create_dataloader()
#      46 for epoch in range(config.epochs):
# ---> 47     for i, item_dict in enumerate(dataloader):
#      48         optimizer.zero_grad()
#      49         # this currently restricts inference up to and including
#      50         # the head to 1 batch...
#
# File ~/miniconda3/envs/equitempo/lib/python3.9/site-packages/torch/utils/data/dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     627 if self._sampler_iter is None:
#     628     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629     self._reset()  # type: ignore[call-arg]
# --> 630 data = self._next_data()
#     631 self._num_yielded += 1
#     632 if self._dataset_kind == _DatasetKind.Iterable and \
#     633         self._IterableDataset_len_called is not None and \
#     634         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/miniconda3/envs/equitempo/lib/python3.9/site-packages/torch/utils/data/dataloader.py:674, in _SingleProcessDataLoaderIter._next_data(self)
#     672 def _next_data(self):
#     673     index = self._next_index()  # may raise StopIteration
# --> 674     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     675     if self._pin_memory:
#     676         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/miniconda3/envs/equitempo/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File ~/miniconda3/envs/equitempo/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File ~/EquiTempo/src/data_loading/datasets.py:210, in FinetuningDataset.__getitem__(self, idx)
#     208     rf_range = self.preprocessing_config.rf_range
#     209     rf = np.random.uniform(rf_range[0], rf_range[1])
# --> 210     audio = librosa.effects.time_stretch(audio, rate=rf)
#     211 else:
#     212     rf = 1
#
# File ~/miniconda3/envs/equitempo/lib/python3.9/site-packages/librosa/effects.py:234, in time_stretch(y, rate, **kwargs)
#     231     raise ParameterError("rate must be a positive number")
#     233 # Construct the short-term Fourier transform (STFT)
# --> 234 stft = core.stft(y, **kwargs)
#     236 # Stretch by phase vocoding
#     237 stft_stretch = core.phase_vocoder(
#     238     stft,
#     239     rate=rate,
#     240     hop_length=kwargs.get("hop_length", None),
#     241     n_fft=kwargs.get("n_fft", None),
#     242 )
#
# File ~/miniconda3/envs/equitempo/lib/python3.9/site-packages/lazy_loader/__init__.py:77, in attach.<locals>.__getattr__(name)
#      75 elif name in attr_to_modules:
#      76     submod_path = f"{package_name}.{attr_to_modules[name]}"
# ---> 77     submod = importlib.import_module(submod_path)
#      78     attr = getattr(submod, name)
#      80     # If the attribute lives in a file (module) with the same
#      81     # name as the attribute, ensure that the attribute and *not*
#      82     # the module is accessible on the package.
#
# File ~/miniconda3/envs/equitempo/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/miniconda3/envs/equitempo/lib/python3.9/site-packages/librosa/core/spectrum.py:16
#      14 from . import convert
#      15 from .fft import get_fftlib
# ---> 16 from .audio import resample
#      17 from .._cache import cache
#      18 from .. import util
#
# File ~/miniconda3/envs/equitempo/lib/python3.9/site-packages/librosa/core/audio.py:1136
#    1130         bwd_pred_error = bwd_pred_error[:-1]
#    1132     return ar_coeffs
#    1135 @stencil  # type: ignore
# -> 1136 def _zc_stencil(x: np.ndarray, threshold: float, zero_pos: bool) -> np.ndarray:
#    1137     """Stencil to compute zero crossings"""
#    1138     x0 = x[0]
#
# File ~/miniconda3/envs/equitempo/lib/python3.9/site-packages/numba/stencils/stencil.py:816, in stencil(func_or_mode, **options)
#     814 wrapper = _stencil(mode, options)
#     815 if func is not None:
# --> 816     return wrapper(func)
#     817 return wrapper
#
# File ~/miniconda3/envs/equitempo/lib/python3.9/site-packages/numba/stencils/stencil.py:826, in _stencil.<locals>.decorated(func)
#     824 from numba.core import compiler
#     825 kernel_ir = compiler.run_frontend(func)
# --> 826 return StencilFunc(kernel_ir, mode, options)
#
# File ~/miniconda3/envs/equitempo/lib/python3.9/site-packages/numba/stencils/stencil.py:83, in StencilFunc.__init__(self, kernel_ir, mode, options)
#      81 self._typingctx = registry.cpu_target.typing_context
#      82 self._targetctx = registry.cpu_target.target_context
# ---> 83 self._typingctx.refresh()
#      84 self._targetctx.refresh()
#      85 self._install_type(self._typingctx)
#
# File ~/miniconda3/envs/equitempo/lib/python3.9/site-packages/numba/core/typing/context.py:158, in BaseContext.refresh(self)
#     153 def refresh(self):
#     154     """
#     155     Refresh context with new declarations from known registries.
#     156     Useful for third-party extensions.
#     157     """
# --> 158     self.load_additional_registries()
#     159     # Some extensions may have augmented the builtin registry
#     160     self._load_builtins()
#
# File ~/miniconda3/envs/equitempo/lib/python3.9/site-packages/numba/core/typing/context.py:701, in Context.load_additional_registries(self)
#     700 def load_additional_registries(self):
# --> 701     from . import (
#     702         cffi_utils,
#     703         cmathdecl,
#     704         enumdecl,
#     705         listdecl,
#     706         mathdecl,
#     707         npydecl,
#     708         setdecl,
#     709         dictdecl,
#     710     )
#     711     self.install_registry(cffi_utils.registry)
#     712     self.install_registry(cmathdecl.registry)
#
# File ~/miniconda3/envs/equitempo/lib/python3.9/site-packages/numba/core/typing/cffi_utils.py:19
#      17 try:
#      18     import cffi
# ---> 19     ffi = cffi.FFI()
#      20 except ImportError:
#      21     ffi = None
#
# File ~/miniconda3/envs/equitempo/lib/python3.9/site-packages/cffi/api.py:65, in FFI.__init__(self, backend)
#      59             raise Exception("Version mismatch: this is the 'cffi' package version %s, located in %r.  This interpreter comes with a built-in '_cffi_backend' module, which is version %s.  The two versions should be equal; check your installation." % (
#      60                 __version__, __file__, backend.__version__))
#      61     # (If you insist you can also try to pass the option
#      62     # 'backend=backend_ctypes.CTypesBackend()', but don't
#      63     # rely on it!  It's probably not going to work well.)
# ---> 65 from . import cparser
#      66 self._backend = backend
#      67 self._lock = allocate_lock()
#
# File ~/miniconda3/envs/equitempo/lib/python3.9/site-packages/cffi/cparser.py:7
#       5     from . import _pycparser as pycparser
#       6 except ImportError:
# ----> 7     import pycparser
#       8 import weakref, re, sys
#      10 try:
#
# File ~/miniconda3/envs/equitempo/lib/python3.9/site-packages/pycparser/__init__.py:15
#      13 import io
#      14 from subprocess import check_output
# ---> 15 from .c_parser import CParser
#      18 def preprocess_file(filename, cpp_path='cpp', cpp_args=''):
#      19     """ Preprocess a file using cpp.
#      20
#      21         filename:
#    (...)
#      30         Errors from cpp will be printed out.
#      31     """
#
# File ~/miniconda3/envs/equitempo/lib/python3.9/site-packages/pycparser/c_parser.py:9
#       1 #------------------------------------------------------------------------------
#       2 # pycparser: c_parser.py
#       3 #
#    (...)
#       7 # License: BSD
#       8 #------------------------------------------------------------------------------
# ----> 9 from .ply import yacc
#      11 from . import c_ast
#      12 from .c_lexer import CLexer
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:846, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:941, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1039, in get_data(self, path)
#
# KeyboardInterrupt:
